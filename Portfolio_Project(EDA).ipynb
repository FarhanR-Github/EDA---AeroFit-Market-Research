# %%
import pandas as pd

# %% [markdown]
# ### **1. Data Exploration and Processing:** :

# %%
# Importing data from drive
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Reading Dataframe
table_data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/EDA/aerofit_treadmill_data (2).csv")
table_data
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
# Checking shape of dataframe 'table_data'
table_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
# Detecting missing values in dataframe

null_values = table_data.isnull()
null_values
# Out:
#      Product    Age  Gender  Education  MaritalStatus  Usage  Fitness  Income  \
# 0      False  False   False      False          False  False    False   False
# 1      False  False   False      False          False  False    False   False
# 2      False  False   False      False          False  False    False   False
# 3      False  False   False      False          False  False    False   False
# 4      False  False   False      False          False  False    False   False
# ..       ...    ...     ...        ...            ...    ...      ...     ...
# 175    False  False   False      False          False  False    False   False
# 176    False  False   False      False          False  False    False   False
# 177    False  False   False      False          False  False    False   False
# 178    False  False   False      False          False  False    False   False
# 179    False  False   False      False          False  False    False   False
#
#      Miles
# 0    False
# ...

# %%
# Total missing values in each column
# Method - 1

table_data.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
# Total missing values in each column
# Method - 2

table_data[["Product","Age","Gender","Education","MaritalStatus","Usage","Fitness","Income","Miles"]].isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
# Checking duplicates in dataset
table_data.duplicated()
table_data
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %% [markdown]
# ### **2. Statistical Summary**

# %%
# Statistical summary for categorical and numerical features

table_data.describe(include = "all")
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      KP281         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %% [markdown]
# ### **Analysis (Statistical Summary):**
#
# The DataFrame "table_data" comprises both numerical and categorical features. As obvious, no statistical calculations be performed over categorical features  like "Product", "Gender", and "MaritalStatus", since they have textual datatype.Above statistics reveal that both numerical and categorical features have no missing values. Mean, std., Min., Q1, Q2, Q3, max. can only be calculated for features with numeric datatype. Dataframe reveals that there is no unique, top and frequently occuring value in numeric columns.

# %% [markdown]
# ### **3. Non Graphical Analysis**

# %%
# Value count for all categorical features
for x in table_data.select_dtypes(include = 'O'):
  print(table_data[x].value_counts())
# Out:
# Product
# KP281    80
# KP481    60
# KP781    40
# Name: count, dtype: int64
# Gender
# Male      104
# Female     76
# Name: count, dtype: int64
# MaritalStatus
# Partnered    107
# Single        73
# Name: count, dtype: int64

# %%
# Unique Attributes for all categorical features

for unique in table_data.select_dtypes(include = 'O'):
  print(unique,":",table_data[unique].unique())
# Out:
# Product : ['KP281' 'KP481' 'KP781']
# Gender : ['Male' 'Female']
# MaritalStatus : ['Single' 'Partnered']

# %% [markdown]
# ### **4. Graphical Analysis**
#
# **Univariate Analysis - Numerical features:**

# %%
# Importing libraries for numerical calculation & plotting graphs
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# **Distribution Plot**

# %%
plt.figure(figsize = (10,5))
for index, col in enumerate(table_data.select_dtypes(include = "int64").columns):
  plt.subplot(2,3,index+1)
  sns.histplot(table_data[col],kde = True)
  plt.title(f"Distribution of {col}")
  plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Count Plots - Numerical**

# %% [markdown]
# **Age**

# %%
# Load the dataset from a CSV file
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/EDA/aerofit_treadmill_data (2).csv")  # Replace "your_file.csv" with your file name
plt.figure(figsize=(5,5))
# Group ages into bins
data['Age_Bins'] = pd.cut(data['Age'], bins=[0, 20, 30, 40, 50], labels=["0-20", "21-30", "31-40", "41-50"])

# Count plot for Age groups
sns.countplot(x=data['Age_Bins'])
plt.title('Count Plot for Age Groups')
plt.xlabel('Age Groups')
plt.ylabel('Count')
plt.show()

# %%
data["Age_Bins"].value_counts()
# Out:
# Age_Bins
# 21-30    110
# 31-40     48
# 41-50     12
# 0-20      10
# Name: count, dtype: int64

# %% [markdown]
# ### **Education**

# %%
plt.figure(figsize = (5,5))

table_data["Education_bin"] = pd.cut(table_data["Education"], bins = [12,14,18,21], labels = ["12-14","15-18","19-21"])

sns.countplot(x = table_data["Education_bin"], hue = table_data["Education_bin"], edgecolor = "black")
plt.title(f"Count plot for Education")
plt.xlabel("Education")
plt.ylabel("Count")
plt.xticks(rotation = 45)
plt.tight_layout()
plt.show()

# %%
table_data["Education_bin"].value_counts()
# Out:
# Education_bin
# 15-18    113
# 12-14     60
# 19-21      4
# Name: count, dtype: int64

# %%
data.columns
# Out:
# Index(['Product', 'Age', 'Gender', 'Education', 'MaritalStatus', 'Usage',
#        'Fitness', 'Income', 'Miles', 'Age_Bins'],
#       dtype='object')

# %% [markdown]
# ### **Usage**

# %%
table_data["Usage"].value_counts()
# Out:
# Usage
# 3    69
# 4    52
# 2    33
# 5    17
# 6     7
# 7     2
# Name: count, dtype: int64

# %%
plt.figure(figsize =(5,5))


data["Usage_Bins"] = pd.cut(data["Usage"], bins = [2,3,5,7], labels = ["2-3","4-5","6-7"])
sns.countplot(x = data["Usage_Bins"], hue = data["Usage_Bins"], edgecolor = "black")
plt.title(f"Count plot for usage_groups")
plt.xlabel("Usage (Avg. no. of times per week)")
plt.ylabel("Count")
plt.xticks(rotation = 45)
plt.tight_layout()
plt.show()

# %%
data["Usage_Bins"].value_counts()
# Out:
# Usage_Bins
# 2-3    69
# 4-5    69
# 6-7     9
# Name: count, dtype: int64

# %% [markdown]
# ### **Fitness**

# %%
plt.figure(figsize=(6,5))
sns.countplot(x = data["Fitness"],hue = data["Fitness"], edgecolor = "blue")
plt.title(f"Fitness Score count")
plt.xlabel("Fitness Score")
plt.ylabel("Count")
plt.xticks(rotation = 45)
plt.tight_layout()
plt.show()

# %%
data["Fitness"].value_counts()
# Out:
# Fitness
# 3    97
# 5    31
# 2    26
# 4    24
# 1     2
# Name: count, dtype: int64

# %% [markdown]
# ## **Income**

# %%
data["Income"].value_counts()
data["Income"].describe()
# Out:
# count       180.000000
# mean      53719.577778
# std       16506.684226
# min       29562.000000
# 25%       44058.750000
# 50%       50596.500000
# 75%       58668.000000
# max      104581.000000
# Name: Income, dtype: float64

# %%
data["Income_bins"] = pd.cut(data["Income"], bins = [25000,45000,65000,85000,105000], labels = ['25000-45000','45001-65000','65001-85000','85001-105000'])
sns.countplot(x = data["Income_bins"], hue = data["Income_bins"],edgecolor = "blue")
plt.title(f"Income Count Plot")
plt.xlabel("Income_level")
plt.ylabel("Count")
plt.xticks(rotation = 45)
plt.tight_layout()
plt.show()

# %%
# Value counts of different income levels

data["Income_bins"].value_counts()
# Out:
# Income_bins
# 45001-65000     103
# 25000-45000      49
# 85001-105000     17
# 65001-85000      11
# Name: count, dtype: int64

# %% [markdown]
# ## **Miles**

# %%
data["Miles_bins"] = pd.cut(data["Miles"], bins = [20,80,140,200,260,320,380], labels = ["20-80",'81-140','141-200','201-260','261-320','321-380'])
sns.countplot(x = data["Miles_bins"], hue = data["Miles_bins"], edgecolor = "blue")
plt.title(f"Count plot for Miles")
plt.xlabel= ("Miles")
plt.ylabel = ("Count")
plt.xticks(rotation = 45)
plt.tight_layout()
plt.show()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
#  9   Age_Bins       180 non-null    category
#  10  Income_bins    180 non-null    category
#  11  Miles_bins     180 non-null    category
# dtypes: category(3), int64(6), object(3)
# memory usage: 13.9+ KB

# %%
data["Miles"].info()
data["Miles"]
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 180 entries, 0 to 179
# Series name: Miles
# Non-Null Count  Dtype
# --------------  -----
# 180 non-null    int64
# dtypes: int64(1)
# memory usage: 1.5 KB

# %%
data["Miles"].describe()
# Out:
# count    180.000000
# mean     103.194444
# std       51.863605
# min       21.000000
# 25%       66.000000
# 50%       94.000000
# 75%      114.750000
# max      360.000000
# Name: Miles, dtype: float64

# %%
# total value count of different mile ranges

data["Miles_bins"].value_counts()
# Out:
# Miles_bins
# 81-140     86
# 20-80      60
# 141-200    28
# 201-260     3
# 261-320     2
# 321-380     1
# Name: count, dtype: int64

# %% [markdown]
# **Box Plot**

# %%
table_data.select_dtypes(include = "number").columns
# Out:
# Index(['Age', 'Education', 'Usage', 'Fitness', 'Income', 'Miles'], dtype='object')

# %%
plt.figure(figsize = (10,8))

for i, bx_plt in enumerate(table_data.select_dtypes(include = "number").columns):

  plt.subplot(2,3,i+1)
  sns.boxplot(table_data[bx_plt])
  plt.title(bx_plt)
  plt.xticks(rotation = 45)
  plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Univariate Analysis - Categorical Features**
#
# **Count Plot**

# %%
table_data.select_dtypes(include = "O").columns
# Out:
# Index(['Product', 'Gender', 'MaritalStatus'], dtype='object')

# %%
plt.figure(figsize=(10, 5))

for index, cnt_plt in enumerate(table_data.select_dtypes(include="O").columns):
  plt.subplot(1, 3, index + 1)
  sns.countplot(x = table_data[cnt_plt])
  plt.title(cnt_plt)
  plt.xticks(rotation=45)
  plt.tight_layout()

plt.show()

# %% [markdown]
# ***Count of each unique value within "Product", "Gender", and "MaritalStatus" columns ***

# %%
#count of different marital statuses
marital_status = table_data["MaritalStatus"].value_counts()
marital_status
# Out:
# MaritalStatus
# Partnered    107
# Single        73
# Name: count, dtype: int64

# %%
# counting male and female members within gender

gender = table_data["Gender"].value_counts()
gender
# Out:
# Gender
# Male      104
# Female     76
# Name: count, dtype: int64

# %%
# Counting number of each product within product column
product = table_data["Product"].value_counts()
product
# Out:
# Product
# KP281    80
# KP481    60
# KP781    40
# Name: count, dtype: int64

# %% [markdown]
# ### **Bivariate Analysis**
#
# **Features effect on product purchased**

# %% [markdown]
# ### **Product v/s Gender**

# %%
sns.countplot(x = table_data["Product"],hue = table_data["Gender"])
plt.show()

# %% [markdown]
# ### **Product v/s Marital Status**

# %%
sns.countplot(x = table_data["Product"], hue = table_data["MaritalStatus"], palette = ["blue","red"], edgecolor = "black")
plt.show()

# %% [markdown]
# ### **Product v/s Age**

# %%
table_data.loc[:,["Product","Age"]].value_counts()
# Out:
# Product  Age
# KP481    25     11
# KP281    23      8
#          25      7
#          26      7
# KP481    23      7
# KP781    25      7
# KP281    28      6
#          24      5
# KP481    33      5
# KP781    24      4
# KP281    38      4
#          21      4
# KP481    35      4
# KP281    22      4
#          19      3
# KP481    40      3
#          31      3
# KP281    35      3
# KP481    24      3
#          20      3
#          21      3
#          26      3
# KP781    22      3
#          23      3
# KP481    34      3
# KP781    27      3
#          28      3
#          30      3
# KP281    27      3
#          29      3
# KP781    29      2
# KP281    20      2
#          31      2
#          32      2
#          34      2
#          33      2
# KP481    38      2
#          30      2
#          32      2
# KP281    30      2
# KP781    26      2
# KP281    18      1
#          40      1
#          50      1
#          39      1
#          37      1
# ...

# %%
sns.countplot(x = table_data["Product"], hue = table_data["Age"], palette = 'viridis', edgecolor  = "b")
plt.show()

# %% [markdown]
# ### **Multivariate Analysis**
#
# **Pair Plot**

# %%
table_data.columns
# Out:
# Index(['Product', 'Age', 'Gender', 'Education', 'MaritalStatus', 'Usage',
#        'Fitness', 'Income', 'Miles'],
#       dtype='object')

# %%
plt.figure(figsize = (10,5))
sns.pairplot(table_data)
plt.show()

# %% [markdown]
# ### **5. Correlation Analysis:**

# %%
num_corr = table_data.corr(numeric_only = True)
sns.heatmap(num_corr, annot = True)
# Out:
# <Axes: >

# %% [markdown]
# Correlation between six numeric variables named "Age","Education","Usage","Fitness","Income", and "Miles" is being portrayed by the heatmap above.
#
# **Strong Correlation**
# Above matrix show that "Usage" has a strong correlation with "Fitness"(0.67) and "Miles"(0.76). Likewise 'Fitness' has a strong positive correlation with 'Miles'
#
# **Moderate Coorelation**
# The heatmap shows that 'Age'(0.51), 'Usage'(0.52), 'Fitness'(0.54), and 'Miles(0.54)' are positively correlated with "Income" but comparatively low intensity correlation.
#
# **Weak Correlation**
# It is obvious that 'Usage", "Fitness", and "Miles" are positively correlated with "Age" but with slight correlation intensity.

# %%
table_data.select_dtypes(include = "int64").columns
# Out:
# Index(['Age', 'Education', 'Usage', 'Fitness', 'Income', 'Miles'], dtype='object')

# %% [markdown]
# ### **6. Outlier Detection**

# %%
print("Outliers")
for o in table_data.select_dtypes(include = "int64"):
  print("\n")
  print(o,":", end = " ")
  IQR = table_data[o].quantile(0.75) - table_data[o].quantile(0.25)
  lower_bound = table_data[o].quantile(0.25) - (1.5 * IQR)
  upper_bound = table_data[o].quantile(0.75) + (1.5 * IQR)
  for x in table_data[o]:
    if x < lower_bound or x > upper_bound:
      print(x, end = " ")
# Out:
# Outliers
#
#
# Age : 47 50 48 47 48
#
# Education : 20 21 21 21
#
# Usage : 6 6 6 7 6 7 6 6 6
#
# Fitness : 1 1
#
# Income : 83416 88396 90886 92131 88396 85906 90886 103336 99601 89641 95866 92131 92131 104581 83416 89641 90886 104581 95508
#
# Miles : 188 212 200 200 200 240 300 280 260 200 360 200 200

# %% [markdown]
# ### **7. Conditional Probabilities:**

# %% [markdown]
# ### **Percent of customers who purchased KP281, KP481, or KP781**

# %%
for x in table_data["Product"].value_counts():
  print(round(x/len(table_data)*100), "% customers purchased",table_data["Product"].iloc[0:3].unique())
# Out:
# 44 % customers purchased ['KP281']
# 33 % customers purchased ['KP281']
# 22 % customers purchased ['KP281']

# %% [markdown]
# ### **Product - Gender Frequency Table**

# %%
table_data.iloc[:,[0,2]].value_counts()
# Out:
# Product  Gender
# KP281    Female    40
#          Male      40
# KP781    Male      33
# KP481    Male      31
#          Female    29
# KP781    Female     7
# Name: count, dtype: int64

# %% [markdown]
# **1. Percentage of a Male customer purchasing a treadmill**

# %%
table_data.iloc[:,[0,2]].value_counts()
count = 0
for x in table_data["Gender"]:
  if x == 'Male':
    count = count + 1
print(round(count/len(table_data)*100),"percent of customers purchased a treadmill are male customers")
# Out:
# 58 percent of customers purchased a treadmill are male customers

# %% [markdown]
# **2. Percentage of Female customers purchasing KP781 treadmill**

# %%
import pandas as pd

count = 0
for product, gender in zip(table_data["Product"], table_data["Gender"]):
  if product == "KP781" and gender == "Female":
    count += 1
print(round(count/len(table_data)*100),"percent of customers purchased a KP781 treadmill are female customers")
# Out:
# 4 percent of customers purchased a KP781 treadmill are female customers

# %% [markdown]
# **3. KP281 - Probability of female customer**

# %%
import pandas as pd
count = 0
for product, gender in zip(table_data["Product"], table_data["Gender"]):
  if product == "KP281" and gender == "Female":
    count += 1


count_total = 0
for product in table_data["Product"]:
  if product == "KP281":
    count_total += 1

Probability = count/count_total
print(Probability,"or",Probability * 100,"% chances are that the customer of KP281 is a female")
# Out:
# 0.5 or 50.0 % chances are that the customer of KP281 is a female

# %% [markdown]
# ### **Frequency Table (Product - Age)**

# %%
PA_frequency = table_data.loc[:,["Product","Age"]].value_counts()
PA_frequency
# Out:
# Product  Age
# KP481    25     11
# KP281    23      8
#          25      7
#          26      7
# KP481    23      7
#                 ..
# KP781    40      1
#          42      1
#          45      1
#          47      1
#          48      1
# Name: count, Length: 68, dtype: int64

# %% [markdown]
# ### ***Percentage of customers with Age between 20s and 30s among all customers ***

# %%
count = 0
for x in table_data["Age"]:
  if x > 20 and x < 30:
    count += 1
print(round(count/len(table_data["Age"]) * 100),"% of customers are between the age of 20s and 30s")
# Out:
# 57 % of customers are between the age of 20s and 30s

# %% [markdown]
# ### **Frequency Table (Product - Income)**

# %%
table_data.iloc[:,[0,7,9]].value_counts()
# Out:
# Product  Income  Income_level
# KP481    45480   Low             9
# KP281    54576   High            7
#          46617   Low             7
#          52302   High            6
# KP481    50028   High            5
# KP281    35247   Low             5
# KP481    53439   High            5
# KP281    45480   Low             5
#          44343   Low             4
# KP481    43206   Low             4
# KP281    40932   Low             4
# KP481    51165   High            4
# KP281    53439   High            3
#          36384   Low             3
#          38658   Low             3
#          51165   High            3
#          32973   Low             3
# KP481    57987   High            3
#          48891   Low             3
# KP781    92131   High            3
#          90886   High            3
# KP481    52302   High            3
#          34110   Low             3
#          40932   Low             2
#          47754   Low             2
# KP281    42069   Low             2
# ...

# %%
# Inc

table_data["Income"].describe()
# Out:
# count       180.000000
# mean      53719.577778
# std       16506.684226
# min       29562.000000
# 25%       44058.750000
# 50%       50596.500000
# 75%       58668.000000
# max      104581.000000
# Name: Income, dtype: float64

# %%
# add a new column "Income_level" and place values as either "High" Or "low"
income_threshold = 50000
table_data["Income_level"] = table_data["Income"].apply(lambda x: "Low" if x < income_threshold else "High")
pd.set_option("display.max_rows",180)
table_data
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# 5     KP281   20  Female         14     Partnered      3        3   32973
# 6     KP281   21  Female         14     Partnered      3        3   35247
# 7     KP281   21    Male         13        Single      3        3   32973
# 8     KP281   21    Male         15        Single      5        4   35247
# 9     KP281   21  Female         15     Partnered      2        3   37521
# 10    KP281   22    Male         14        Single      3        3   36384
# 11    KP281   22  Female         14     Partnered      3        2   35247
# ...

# %% [markdown]
# **Percentage of a low-income customer purchasing a treadmill**

# %%
count = 0
for x in table_data["Income_level"]:
  if x == "Low":
    count += 1

Low_count = 0
for x, y in zip(table_data["Income_level"],table_data["Product"]):
  if x == "Low" and y in ["KP281","KP481","KP781"]:
    Low_count += 1

Low_income_percent = Low_count/count * 100
print(round(Low_income_percent),"percent low income customers purchasing a treadmill")
# Out:
# 100 percent low income customers purchasing a treadmill

# %% [markdown]
# **Percentage of a high-income customer purchasing KP781 treadmill**

# %%
count = 0
for x in table_data["Income_level"]:
  if x == "High":
    count += 1

count_high = 0
for x, y in zip(table_data["Income_level"],table_data["Product"]):
  if x == "High" and y == "KP781":
    count_high += 1

high_income_percent = count_high/count * 100
print(round(high_income_percent),"percent high income earners purchased 'KP781'")
# Out:
# 36 percent high income earners purchased 'KP781'

# %% [markdown]
# **Percentage of high-income earners buying treadmill given that Product is KP781**

# %%
count = 0
for x, y in zip(table_data["Income_level"],table_data["Product"]):
  if x in ["High","Low"] and y == "KP781":
    count += 1

count_high = 0
for x, y in zip(table_data["Income_level"],table_data["Product"]):
  if x == "High" and y == "KP781":
    count_high += 1

high_income_KP781 = count_high/count * 100
print(round(high_income_KP781),"percent customers are high income earners and purchased KP781")
# Out:
# 88 percent customers are high income earners and purchased KP781

# %% [markdown]
# ### **Frequency Table (Product - Fitness)**

# %%
table_data.iloc[:,[0,6]].value_counts()
# Out:
# Product  Fitness
# KP281    3          54
# KP481    3          39
# KP781    5          29
# KP281    2          14
# KP481    2          12
# KP281    4           9
# KP481    4           8
# KP781    4           7
#          3           4
# KP281    5           2
#          1           1
# KP481    1           1
# Name: count, dtype: int64

# %% [markdown]
# **Percentage of customers having fitness level 5**

# %%
count = 0
for fit in table_data["Fitness"]:
  if fit == 5:
    count += 1
customer_percent = count/(len(table_data["Fitness"])) * 100
print(round(customer_percent),"% of customers have a fitness level of 5")
# Out:
# 17 % of customers have a fitness level of 5

# %% [markdown]
# **Percentage of a customer with Fitness Level 5 purchasing KP781 treadmill**

# %%
count = 0
for x in table_data["Fitness"]:
  if x == 5:
    count += 1

total_count = 0
for x, product in zip(table_data["Fitness"], table_data["Product"]):
  if x == 5 and product == "KP781":
    total_count += 1
customer_percent = total_count/count * 100
print(round(customer_percent),"% customers having fitness level 5 and purchase KP781")
# Out:
# 94 % customers having fitness level 5 and purchase KP781

# %% [markdown]
# **Percentage of customer with Fitness Level 5 buying KP781 treadmill**

# %%
count = 0
for x in table_data["Product"]:
  if x == "KP781":
    count += 1

count_total = 0
for x, y in zip(table_data["Product"],table_data["Fitness"]):
  if x == "KP781" and y == 5:
    count_total += 1

customer_percent = count_total/count * 100
print(round(customer_percent),"% customers who are buying KP781 are also having fitness level 5")
# Out:
# 72 % customers who are buying KP781 are also having fitness level 5

# %% [markdown]
# ### **Frequency Table (Product - Marital Status)**

# %%
table_data.iloc[:,[0,4]].value_counts()
# Out:
# Product  MaritalStatus
# KP281    Partnered        48
# KP481    Partnered        36
# KP281    Single           32
# KP481    Single           24
# KP781    Partnered        23
#          Single           17
# Name: count, dtype: int64

# %% [markdown]
# **Percentage of customers who are partnered using treadmill**

# %%
count = 0
for x, y in zip(table_data["MaritalStatus"],table_data["Product"]):
  if x in ("Partnered","Single") and y in ("KP281","KP481","KP781"):
    count += 1

count_total = 0
for x, y in zip(table_data["MaritalStatus"],table_data["Product"]):
  if x == "Partnered" and y in ("KP281","KP481","KP781"):
    count_total += 1

customer_percentage = count_total/count * 100
print(round(customer_percentage,2),"% customers using treadmill are partnered")
# Out:
# 59.44 % customers using treadmill are partnered

# %% [markdown]
# # **Report**

# %% [markdown]
# This report summarizes the findings from the Exploratory Data Analysis (EDA) conducted on the Aerofit treadmill dataset. It highlights key insights and offers actionable recommendations for Aerofit to enhance its marketing and sales strategies.
#
# ### **Actionable Insights**
# **Product Preference by Gender and Marital Status:**
#
# The KP781 treadmill is the most popular product overall.
# Males and partnered individuals tend to purchase the KP781 more frequently.
# KP281 is preferred by females and is a more affordable entry-level option.
#
# **Fitness and Usage Influence Purchase:**
#
# Customers with higher fitness levels and usage frequency tend to purchase the advanced KP781.
# The KP481 is often chosen by customers with moderate fitness levels.
# Consider promoting the KP281 to less frequent users, positioning it as an initiation to a healthier lifestyle.
#
# **Income's Impact on Product Choice:**
#
# High-income earners favor the KP781, validating its premium positioning.
# Customers with lower incomes are more likely to purchase the KP281 or KP481.
# Offer targeted promotions or financing options for the more expensive models to customers with moderate incomes.
#
# **Miles and Fitness Correlation:**
#
# There's a strong correlation between miles run and fitness level.
# Customers aiming for longer distances prefer the KP781, highlighting its ability to support demanding workouts.
# Consider emphasizing this feature in marketing materials for the KP781.
#
# **Age Demographics:**
#
# The majority of customers are between 20 and 30 years old.
# Consider tailoring marketing campaigns to this age group, leveraging popular social media platforms.
# Explore ways to attract older demographics by highlighting the benefits of treadmills for maintaining health and fitness.
#
# **Education Level:**
#
# There's a positive correlation between education level and product purchase.
# Tailor marketing messaging to resonate with customers who value quality and innovation (KP781).
#
# ### **Recommendations:**
#
# **Targeted Marketing Campaigns:**
#
# Create separate marketing campaigns for each product, targeting specific demographics.
# Highlight the features and benefits that align with the needs and motivations of each customer segment (age, income, fitness level, usage frequency).
# Personalize marketing messages based on gender and marital status to increase engagement.
#
# **Product Bundling and Promotions:**
#
# Offer bundles that include accessories, fitness programs, or maintenance plans to incentivize purchase of premium models.
# Implement strategic promotions for the KP481 and KP281 to attract customers in lower income brackets.
# Provide financing options or discounts for students and young professionals.
#
# **Customer Retention:**
#
# Develop loyalty programs to reward existing customers for repeat purchases and referrals.
# Offer personalized fitness guidance and product recommendations to enhance customer satisfaction.
# Focus on building relationships and creating a community around Aerofit products.
#
# **Product Development:**
#
# Explore new features and designs to cater to a wider range of customer needs.
# Research emerging trends in fitness technology and consumer behavior.
# Innovation can ensure long-term growth and market competitiveness.
#
# **Channel Optimization:**
#
# Analyze sales data to identify the most effective channels for reaching target audiences.
# Invest in digital marketing strategies to enhance online visibility and lead generation.
# Develop partnerships with gyms, fitness studios, or health professionals for co-marketing opportunities.
#
# ### **Conclusion**
#
# By acting upon these insights and implementing the recommendations provided, Aerofit can enhance its sales strategies, improve customer acquisition and retention, and maximize profitability. This data-driven approach allows for more informed decision-making and lays the groundwork for sustainable growth in the competitive fitness market.
